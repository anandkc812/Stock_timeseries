# %% [markdown]
# <a href="https://colab.research.google.com/github/anandkc812/Stock_timeseries/blob/master/Currency_Prediction_Fraud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #This program check the fradulant claim :
#
#  Some websites claim to offer simple tricks of making money
#    - by periodically - increasing stakes/bets in opposite direction.
#
#
#  Modus:
#
#
#     1) First start with a small bet. Predict currency will go -up or down
#     2) If - bet on one direction goes wrong -
#               - Double the bet value and apply on the opposite direction.
#               - Say in step 1, if we bet on currency up,
#                    then this time place bet on currency down.
#     3)  Repeat step 2 - untill you book profit.
#     4)  After recovering the money - start again from step 1 to 3.

# %%
# !pip install alpha_vantage


import requests
import alpha_vantage
import json

# %%
import requests
import alpha_vantage
import json


API_URL = "https://www.alphavantage.co/query" 

data = { "function": "FX_INTRADAY", 
"from_symbol" : "USD",
"to_symbol": "INR",
"interval" : "15min",       
"datatype": "json", 
"apikey": "YVUP6HULNB1LOADW" } 
response = requests.get(API_URL, data) 
data = response.json()
print(symbol)
print(data)
#a = (data["Realtime Currency Exchange Rate"])
#keys = (a.keys())
#for key in keys:
#    print(a[key]['4. To_Currency Name'] + " " + a[key]["5. Exchange Rate"])


a = (data["Time Series FX (15min)"])
keys = (a.keys())
for key in keys:
        print(key, a[key]['1. open'])
# Out:
# INR
# ...

# %%
def toss():
  random
